# %%
import duckdb
import ujson as json
import pandas as pd
from rich.console import Console

from ydata_profiling import ProfileReport

# %%
with open('../jace/.cache/jace_sets.json', 'r', encoding='utf-8') as f:
    data = json.loads(f.read())

# %%
df = pd.DataFrame(data)

df.head(10)
# Out:
#   object                                    id  code mtgo_code arena_code  \
# 0    set  d33ef7a4-41bb-4f16-bad3-b3ee13c257e6   drc       drc        drc
# 1    set  23464cc2-a69c-427d-b8a7-08e5d80235d7   dft       dft        dft
# 2    set  cc05a3a1-fb38-4d6d-b3d3-032e90b49d00  pdft       NaN        NaN
# 3    set  3916f769-ad69-4527-9700-33b266113013  tdft       NaN        NaN
# 4    set  f51d00d3-6ab4-4fa9-90ce-702aed612e9b  tdrc       NaN        NaN
# 5    set  6a1e8cf5-a516-4fc2-8d99-96862f4117f9  pjsc       NaN        NaN
# 6    set  03368b5a-dcb8-4742-bf70-f194718d0bc8  ainr       NaN        NaN
# 7    set  b9618c8c-9f31-4b42-9798-2991893c27bf   inr       NaN        NaN
# 8    set  de27268e-c9c5-4d97-9bfd-28ad8cb7b1a0  tinr       NaN        NaN
# 9    set  053b14b2-b622-44ce-a695-5881e2580e1d  pspl       NaN        NaN
#
#    tcgplayer_id                             name  \
# 0       23929.0            Aetherdrift Commander
# 1       23874.0                      Aetherdrift
# ...

# %%
df.describe()
# Out:
#        tcgplayer_id   card_count  printed_size
# count    340.000000   944.000000    169.000000
# mean    4052.523529   109.861229    178.869822
# std     7421.598643   246.067305    110.230201
# min        1.000000     0.000000      6.000000
# 25%       73.750000     6.000000     63.000000
# 50%     1513.500000    20.500000    184.000000
# 75%     2709.250000   143.250000    269.000000
# max    23929.000000  4878.000000    383.000000

# %%
profile = ProfileReport(df, title="Jace Sets")

# %%
with open('../jace/.cache/jace_all_cards.json', 'r', encoding='utf-8') as f:
    data = json.loads(f.read())

all_cards_df = pd.DataFrame(data)
all_cards_df.head(10)
# Out:
#   object                                    id  \
# 0   card  0000419b-0bba-4488-8f7a-6194544ce91e
# 1   card  0000579f-7b35-4ed3-b44c-db2a538066fe
# 2   card  00006596-1166-4a79-8443-ca9f82e6db4e
# 3   card  00009878-d086-46f0-a964-15734d8368ac
# 4   card  0000a54c-a511-4925-92dc-01b937f9afad
# 5   card  0000cd57-91fe-411f-b798-646e965eec37
# 6   card  00011897-9c8b-482f-8d64-9f2cd8403b6a
# 7   card  00012bd8-ed68-4978-a22d-f450c8a6e048
# 8   card  00014127-a9d2-4e01-ae79-2349e8989793
# 9   card  0001680b-82ac-48aa-9416-f97cacc745ef
#
#                               oracle_id multiverse_ids   mtgo_id  arena_id  \
# 0  b34bb2dc-c1af-4d77-b0b3-a0fb342a5fc6       [668564]  129825.0   91829.0
# 1  44623693-51d6-49ad-8cd7-140505caf02f       [109722]   25527.0       NaN
# 2  8ae3562f-28b7-4462-96ed-be0cf7052ccc       [189637]   34586.0       NaN
# 3  30cd69a8-7893-4075-94ca-04450ff821d3       [433932]       NaN       NaN
# ...

# %%
all_cards_df.describe()
# Out:
#              mtgo_id      arena_id   tcgplayer_id             cmc  \
# count   52644.000000  15846.000000   89339.000000   492437.000000
# mean    70105.191266  79391.230973  234889.483126        7.059552
# std     37417.349710  10128.412782  194998.669103     2015.292635
# min         9.000000   6993.000000      86.000000        0.000000
# 25%     36848.500000  71963.250000   67579.500000        2.000000
# 50%     67407.000000  79337.500000  202650.000000        3.000000
# 75%    104458.500000  87012.750000  452830.500000        4.000000
# max    133894.000000  96355.000000  610803.000000  1000000.000000
#
#         mtgo_foil_id  cardmarket_id    edhrec_rank     penny_rank  \
# count   24312.000000   78331.000000  463358.000000  315428.000000
# mean    38003.923988  376738.652194   11274.654261    7287.636171
# std     19187.558613  268470.153950    8454.637598    4980.842090
# min       303.000000       1.000000       1.000000       5.000000
# ...

# %%
all_cards_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 492491 entries, 0 to 492490
# Data columns (total 86 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   object               492491 non-null  object
#  1   id                   492491 non-null  object
#  2   oracle_id            492437 non-null  object
#  3   multiverse_ids       492491 non-null  object
#  4   mtgo_id              52644 non-null   float64
#  5   arena_id             15846 non-null   float64
#  6   tcgplayer_id         89339 non-null   float64
#  7   name                 492491 non-null  object
#  8   lang                 492491 non-null  object
#  9   released_at          492491 non-null  object
#  10  uri                  492491 non-null  object
#  11  scryfall_uri         492491 non-null  object
#  12  layout               492491 non-null  object
#  13  highres_image        492491 non-null  bool
#  14  image_status         492491 non-null  object
# ...

# %%
db = duckdb.connect(':memory:')

duck_df = db.from_df(all_cards_df)
# https://duckdb.org/docs/guides/python/jupyter.html

# %%
# %load_ext sql
# Out:
# C:\Users\TheCaptain\AppData\Local\pypoetry\Cache\virtualenvs\jace-the-bot-gf12GtR1-py3.12\Lib\site-packages\sql\parse.py:338: SyntaxWarning: invalid escape sequence '\:'
#   """
# C:\Users\TheCaptain\AppData\Local\pypoetry\Cache\virtualenvs\jace-the-bot-gf12GtR1-py3.12\Lib\site-packages\sql\parse.py:368: SyntaxWarning: invalid escape sequence '\:'
#   """
# The 'toml' package isn't installed. To load settings from pyproject.toml or ~/.jupysql/config, install with: pip install toml

# %%
conn = duckdb.connect()
# %sql conn --alias duckdb
